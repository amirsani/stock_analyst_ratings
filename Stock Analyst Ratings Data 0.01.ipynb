# %%
import pickle

# %% [markdown]
# ## Get the data from the pickle file

# %%
filename = 'stock_analyst_ratings.pickle'
with open(filename, 'rb') as handle:
    stock_analyst_ratings = pickle.load(handle)

# %% [markdown]
# ## Get the list of analyst keys

# %%
dictionary_keys = list(stock_analyst_ratings.keys())

# %% [markdown]
# ## Example Ratings

# %%
stock_analyst_ratings[dictionary_keys[10]]
# Out:
#            Stock     Action
# Date
# 2014-05-05  FEIC    Upgrade
# 2013-01-28  FEIC  Downgrade
# 2011-11-29  FEIC  Initiated
# 2002-08-22  CHKP  Initiated
# 2015-04-17  FCEL  Initiated
# 2012-10-15  ULTI  Downgrade
# 2011-02-09  ULTI    Upgrade
# 2008-10-30  ULTI  Downgrade
# 2008-09-11  ULTI  Initiated
# 2008-09-10  ULTI  Initiated
# 2016-03-11  RAVN  Downgrade
# 2010-05-21  RAVN    Upgrade
# 2008-11-21  RAVN  Downgrade
# 2008-05-20  RAVN    Upgrade
# 2008-03-13  RAVN  Downgrade
# 2004-05-25  RAVN  Initiated
# 2002-12-18  ATVI  Downgrade
# 2002-12-13  ATVI  Downgrade
# 2002-07-23  ATVI    Upgrade
# 2001-06-14  ATVI  Downgrade
# 2011-03-22  NTCT  Downgrade
# 2011-05-13  LLNW    Upgrade
# 2011-02-16  LLNW  Downgrade
# 2011-01-03  LLNW    Upgrade
# 2016-01-14  ADBE  Initiated
# 2013-02-21  TASR  Downgrade
# 2010-04-05  TASR  Downgrade
# 2009-10-23  TASR    Upgrade
# 2009-01-05  TASR  Downgrade
# 2007-06-11  TASR  Initiated
# ...          ...        ...
# 2016-09-21  DTSI  Downgrade
# ...
